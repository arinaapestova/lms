# %% [markdown]
# <a href="https://colab.research.google.com/github/arinaapestova/lms/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jul  8 11:02:59 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Y9pm57IUQFQgQU54JIqB")
project = rf.workspace("p-2qfmt").project("cars-bl2db")
dataset = project.version(1).download("yolov8")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov8 in progress : 85.0%
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to cars-1 in yolov8:: 100%|██████████| 306/306 [00:00<00:00, 6178.58it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 308MB/s]
# New https://pypi.org/project/ultralytics/8.2.51 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    P_curve.png		train_batch121.jpg
# confusion_matrix_normalized.png			    PR_curve.png	train_batch122.jpg
# confusion_matrix.png				    R_curve.png		train_batch1.jpg
# events.out.tfevents.1720436872.7424a03fadc3.1947.0  results.csv		train_batch2.jpg
# F1_curve.png					    results.png		val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	val_batch0_pred.jpg
# labels.jpg					    train_batch120.jpg	weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/cars-1/valid/labels.cache... 20 images, 0 backgrounds, 0 corrupt: 100% 20/20 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.18s/it]
#                    all         20         33      0.966          1      0.994      0.961
# Speed: 15.9ms preprocess, 28.7ms inference, 0.0ms loss, 52.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/10 /content/datasets/cars-1/test/images/1426274569_honda-civ_jpg.rf.e057294eaa1c344cdc73949e2a0cf560.jpg: 800x800 2 carss, 22.6ms
# image 2/10 /content/datasets/cars-1/test/images/1920x1440_1610208_-www-ArtFile-ru-_jpg.rf.8fffbf2f050b21c215e4b0bcc1e09fba.jpg: 800x800 1 cars, 22.5ms
# image 3/10 /content/datasets/cars-1/test/images/1921527_jpg.rf.984168caa40a2b95d67a06a4bdc446ba.jpg: 800x800 5 carss, 22.5ms
# image 4/10 /content/datasets/cars-1/test/images/348b80ds-1920_jpg.rf.89cced052d7056416b763654fba267c0.jpg: 800x800 1 cars, 22.5ms
# image 5/10 /content/datasets/cars-1/test/images/6EAAAgB8cOA-1920_jpg.rf.6450e4b21216f5aaac99d3e9c8b600c3.jpg: 800x800 1 cars, 22.6ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg'):
      display(Image(filename=image_path, width=600))
      print("\n")
